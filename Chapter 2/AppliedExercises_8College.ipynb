# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 8(a)

college = pd.read_csv('../Files/College.csv')

# %%
# 8(b) 

college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
#      Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# 0           52         2885          537      7440        3300    450
# 1           29         2683         1227     12280        6450    750
# 2           50         1036           99     11250        3750    400
# 3           89          510           63     12960        5450    450
# 4           44          249          869      7560        4120    800
# ..         ...          ...          ...       ...         ...    ...
# 772         26         3089         2029      6797        3900    500
# 773         47         2849         1107     11520        4960    600
# 774         61         2793          166      6900        4200    617
# 775         99         5217           83     19840        6510    630
# 776         63         2988         1726      4990        3560    500
#
#      Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0        2200   70        78       18.1           12    7041         60
# 1        1500   29        30       12.2           16   10527         56
# 2        1165   53        66       12.9           30    8735         54
# 3         875   92        97        7.7           37   19016         59
# 4        1500   76        72       11.9            2   10922         15
# ..        ...  ...       ...        ...          ...     ...        ...
# 772      1200   60        60       21.0           14    4469         40
# 773      1250   73        75       13.3           31    9189         83
# 774       781   67        75       14.4           20    8323         49
# 775      2115   96        96        5.8           49   40386         99
# 776      1250   75        75       18.1           28    4509         99
#
# [777 rows x 19 columns]

# %%
#Removed the first column
college = college.drop('Unnamed: 0',axis=1)

college
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0            537      7440        3300    450      2200   70        78
# 1           1227     12280        6450    750      1500   29        30
# 2             99     11250        3750    400      1165   53        66
# 3             63     12960        5450    450       875   92        97
# 4            869      7560        4120    800      1500   76        72
# ..           ...       ...         ...    ...       ...  ...       ...
# 772         2029      6797        3900    500      1200   60        60
# 773         1107     11520        4960    600      1250   73        75
# 774          166      6900        4200    617       781   67        75
# 775           83     19840        6510    630      2115   96        96
# 776         1726      4990        3560    500      1250   75        75
#
#      S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0         18.1           12    7041         60
# 1         12.2           16   10527         56
# 2         12.9           30    8735         54
# 3          7.7           37   19016         59
# 4         11.9            2   10922         15
# ..         ...          ...     ...        ...
# 772       21.0           14    4469         40
# 773       13.3           31    9189         83
# 774       14.4           20    8323         49
# 775        5.8           49   40386         99
# 776       18.1           28    4509         99
#
# [777 rows x 18 columns]

# %%
# 8(c)i. 

college.describe().transpose()
# Out:
#              count          mean          std     min     25%     50%  \
# Apps         777.0   3001.638353  3870.201484    81.0   776.0  1558.0
# Accept       777.0   2018.804376  2451.113971    72.0   604.0  1110.0
# Enroll       777.0    779.972973   929.176190    35.0   242.0   434.0
# Top10perc    777.0     27.558559    17.640364     1.0    15.0    23.0
# Top25perc    777.0     55.796654    19.804778     9.0    41.0    54.0
# F.Undergrad  777.0   3699.907336  4850.420531   139.0   992.0  1707.0
# P.Undergrad  777.0    855.298584  1522.431887     1.0    95.0   353.0
# Outstate     777.0  10440.669241  4023.016484  2340.0  7320.0  9990.0
# Room.Board   777.0   4357.526384  1096.696416  1780.0  3597.0  4200.0
# Books        777.0    549.380952   165.105360    96.0   470.0   500.0
# Personal     777.0   1340.642214   677.071454   250.0   850.0  1200.0
# PhD          777.0     72.660232    16.328155     8.0    62.0    75.0
# Terminal     777.0     79.702703    14.722359    24.0    71.0    82.0
# S.F.Ratio    777.0     14.089704     3.958349     2.5    11.5    13.6
# perc.alumni  777.0     22.743887    12.391801     0.0    13.0    21.0
# Expend       777.0   9660.171171  5221.768440  3186.0  6751.0  8377.0
# Grad.Rate    777.0     65.463320    17.177710    10.0    53.0    65.0
#
#                  75%      max
# Apps          3624.0  48094.0
# Accept        2424.0  26330.0
# Enroll         902.0   6392.0
# Top10perc       35.0     96.0
# Top25perc       69.0    100.0
# F.Undergrad   4005.0  31643.0
# P.Undergrad    967.0  21836.0
# Outstate     12925.0  21700.0
# Room.Board    5050.0   8124.0
# Books          600.0   2340.0
# Personal      1700.0   6800.0
# PhD             85.0    103.0
# Terminal        92.0    100.0
# S.F.Ratio       16.5     39.8
# perc.alumni     31.0     64.0
# Expend       10830.0  56233.0
# Grad.Rate       78.0    118.0

# %%
# 8(c)ii. 

# Private column is categorical and this function only plots numerical
# so I added the hue parameter for Private feature. 
sns.pairplot(data=college.iloc[:,0:10],hue='Private')
plt.show()

# %%
# 8(c)iii. 

plt.figure(figsize=(5,5),dpi=150)
sns.boxplot(data=college,x='Private',y='Outstate')
plt.show()

# %%
# 8(c)iv. 

college['Elite'] = college['Top10perc'] > 50

# %%
college['Elite'].value_counts()
# Out:
# False    699
# True      78
# Name: Elite, dtype: int64

# %%
plt.figure(figsize=(5,5),dpi=150)
sns.boxplot(data=college,x='Elite',y='Outstate');

# %%
# 8(c)v. 

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(5,5),dpi=150)

axs[0,0].hist(data=college,x='Outstate',bins=30)
axs[0,1].hist(data=college,x='Enroll',bins=30)
axs[1,0].hist(data=college,x='Room.Board',bins=30)
axs[1,1].hist(data=college,x='Books',bins=30)

axs[0,0].set_title('Outstate')
axs[0,1].set_title('Enroll')
axs[1,0].set_title('Room Board')
axs[1,1].set_title('Books')

plt.tight_layout()
plt.show()

# %%
# 8(c)vi. Continue exploring the data, and provide a brief summary
# of what you discover.

fig, axs = plt.subplots(nrows=1, ncols=2,figsize=(6,3),dpi=200)

sns.scatterplot(ax=axs[0],data=college,x='Apps',y='Accept',hue='Private')
sns.scatterplot(ax=axs[1],data=college,x='Apps',y='Outstate',hue='Private')

axs[0].set_title('Accept vs Apps')
axs[1].set_title('Outstate vs Apps')

plt.tight_layout()
plt.show()

# %% [markdown]
# **8(c)vi.**
#
# I was curious about the number of applicants that applied to private institutions, so
# we see that a lot of private institutions received applications from students out of state.
# This coincides with the Accept vs Apps graph that shows that Private institutions acceptance rate
# is quite low compared to public colleges.
