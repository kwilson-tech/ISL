# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 9 

Auto = pd.read_csv('../Files/Auto.csv')
Auto = Auto.dropna()

# %%
Auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   year          392 non-null    int64
#  7   origin        392 non-null    int64
#  8   name          392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 30.6+ KB

# %%
Auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 387       1            ford mustang gl
# 388       2                  vw pickup
# 389       1              dodge rampage
# 390       1                ford ranger
# 391       1                 chevy s-10
#
# [392 rows x 9 columns]

# %%
Auto['origin'].unique()
# Out:
# array([1, 3, 2], dtype=int64)

# %% [markdown]
# **9(a)**
#
# Quantitative predictors - 'mpg', 'cylinders', 'displacement', 'horsepower', 'weight','acceleration','year'
#
# Qualitative predictors - 'name', 'origin'

# %%
# 9(b) 

Auto.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')

# %%
a = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'year']

a = Auto[a]

# %%
# Range
a.apply(lambda x: (x.max()-x.min()))
# Out:
# mpg               37.6
# cylinders          5.0
# displacement     387.0
# horsepower       184.0
# weight          3527.0
# acceleration      16.8
# year              12.0
# dtype: float64

# %%
# 9(c) 

# Mean
a.apply(lambda x: x.mean())
# Out:
# mpg               23.445918
# cylinders          5.471939
# displacement     194.411990
# horsepower       104.469388
# weight          2977.584184
# acceleration      15.541327
# year              75.979592
# dtype: float64

# %%
# Standard Deviation
a.apply(lambda x: x.std())
# Out:
# mpg               7.805007
# cylinders         1.705783
# displacement    104.644004
# horsepower       38.491160
# weight          849.402560
# acceleration      2.758864
# year              3.683737
# dtype: float64

# %%
# 9(d) 

a = a.drop(a.index[10:86])

# %%
# Range
a.apply(lambda x: (x.max()-x.min()))
# Out:
# mpg               35.6
# cylinders          5.0
# displacement     387.0
# horsepower       184.0
# weight          3348.0
# acceleration      16.3
# year              12.0
# dtype: float64

# %%
# Mean
a.apply(lambda x: x.mean())
# Out:
# mpg               24.407595
# cylinders          5.373418
# displacement     187.512658
# horsepower       100.848101
# weight          2936.534810
# acceleration      15.717405
# year              77.136076
# dtype: float64

# %%
# Standard Deviation
a.apply(lambda x: x.std())
# Out:
# mpg               7.863285
# cylinders         1.654179
# displacement    100.114616
# horsepower       35.954147
# weight          811.874450
# acceleration      2.713876
# year              3.123464
# dtype: float64

# %%
# 9(e) 

sns.pairplot(data=Auto)
plt.show()

# %% [markdown]
# **9(e)**
# Answer:
# For mpg, it has a negative slope with weight, horsepower, and displacement. When it comes to cylinders, you can see that the higher the cylinder count there is a likelihood that the displacement and the weight could be high. However, when it comes to mpg the possible range of values decreases as the cylinder value increases. Displacement shows a positive slope with weight and horsepower. The accleration variable shows a negative slope with the weight, horsepower, and displacement.
#
#
#
# **9(f)**
# Answer:
# The variables displacement,horsepower,weight,acceleration,year,and origin shows a strong relationship with mpg.
# The relationship is shown with the behavior of the origin predictor when analyzed across other variables.
# mpg vs displacement shows a negative slope meaning the higher the mpg the lower the displacement.
# mpg vs horsepower shows a negative slope meaning the higher the mpg the lower the horsepower.
# mpg vs weight shows a negative slope meaning the higher the mpg the lower the weight of the vehicle.
# mpg vs acceleration shows a more positive slope when their are limits placed on the domain. Around 15mph,
# is where the function curves upward.
