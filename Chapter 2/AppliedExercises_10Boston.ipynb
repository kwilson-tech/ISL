# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 10(a) 

Boston = pd.read_csv('../Files/Boston.csv')

# %%
# Answer: 506 rows and 14 columns. Columns represent the attribues of the city or town.
Boston
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio  lstat  medv
# ...

# %%
# 10(b)

Boston.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'lstat', 'medv'],
#       dtype='object')

# %%
Boston[['rad','chas','zn']].nunique()
# Out:
# rad      9
# chas     2
# zn      26
# dtype: int64

# %%
sns.pairplot(data=Boston.iloc[:,1:])
plt.show()

# %% [markdown]
# **10(c)**
#
# crim vs medv has a negative slope because it shows that the crime per capita is low when the
# median value of the home is high and when the crime per capita is high the median value of the home is low
#
# crim vs ptratio shows that the teacher to student ratio is low in areas with low crime, but the
# crime rate is high in areas with higher levels of crime
#
# crim vs nox shows that areas with higher levels of crime has a higher nitric oxide concentration

# %%
# 10(d) 

Boston.describe()[['crim','tax','ptratio']]
# Out:
#              crim         tax     ptratio
# count  506.000000  506.000000  506.000000
# mean     3.613524  408.237154   18.455534
# std      8.601545  168.537116    2.164946
# min      0.006320  187.000000   12.600000
# 25%      0.082045  279.000000   17.400000
# 50%      0.256510  330.000000   19.050000
# 75%      3.677083  666.000000   20.200000
# max     88.976200  711.000000   22.000000

# %% [markdown]
# **Answer:**
#
# The maximum crime rate is extremely high compared to the median given in the dataset and even given the mean.
#
# The maximum tax rate given is not within 1 std but the range from the 75 percentile group is not as large
# compared to the crime rate.
#
# The maximum pupil teacher ratio value is very close to the mean meaning the distribution of the dataset
# is close to each other.

# %%
# 10(e) 

len(Boston[Boston['chas'] == 1])
# Out:
# 35

# %%
# 10(f) 

Boston['ptratio'].median()
# Out:
# 19.05

# %%
# 10(g) 

Boston.iloc[Boston['medv'].idxmin(),:]
# Out:
# Unnamed: 0    399.0000
# crim           38.3518
# zn              0.0000
# indus          18.1000
# chas            0.0000
# nox             0.6930
# rm              5.4530
# age           100.0000
# dis             1.4896
# rad            24.0000
# tax           666.0000
# ptratio        20.2000
# lstat          30.5900
# medv            5.0000
# Name: 398, dtype: float64

# %%
Boston.describe().transpose()[1:]
# Out:
#          count        mean         std        min         25%        50%  \
# crim     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# zn       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# indus    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# chas     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# nox      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# rm       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# age      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# dis      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# rad      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# tax      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# ptratio  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# lstat    506.0   12.653063    7.141062    1.73000    6.950000   11.36000
# ...

# %% [markdown]
# **Answer:**
#
# The crime rate is extremely high compared to the mean. The ptratio variation is not that big with the other
# values in Boston so their is not a lot of varation in each town.
#
# Nitric oxide concentration is higher than the mean but not by much
#
# The towns tax rate is higher than the average rate in Boston
#
# The town has about 30% of the lower status popluation (lstat) that reside in their area
#
# The town is also not near a river and shows that the age of the owner occupied units built prior to 1940
# is higher than the mean of Boston.

# %%
# 10(h) 

len(Boston[Boston['rm'] > 7])
# Out:
# 64

# %%
len(Boston[Boston['rm'] > 8])
# Out:
# 13

# %%
Boston[Boston['rm'] > 8].iloc[:,1:]
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 97   0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 163  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 224  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 225  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 226  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 232  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 233  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 253  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 257  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 262  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 267  0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# ...

# %% [markdown]
# **Answer:**
#
# The crime rate is either lower or around the average crime rate in Boston
# The bulk of the areas are not near a river and the percentage of the lower status population is low.
# The bulk of the values also show that the median value of the homes are higher than the average and the
# property tax rate is lower than the average of Boston as well.
